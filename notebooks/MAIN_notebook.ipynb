# %% [markdown]
# ## UTAH FORGE WELL 58-32
#
# **Well 58-32 was drilled to a depth of 7536 feet** in the Milford FORGE area during the summer of
# 2017 to confirm the reservoir characteristics inferred from existing wells and a wide variety of
# both new and legacy geologic and geophysical data. **Drill cuttings were collected and described
# at 10-foot intervals** and a robust **suite of geophysical logs** were run. Analyses show
# that the basement rock within the FORGE area consists of a suite of **intrusive rock types that are
# primarily granitic. Some diorite and monzodiorite was also encountered**, as was a significant
# volume of rock with a more intermediate composition.
#
# The density of the granite and intermediate rock types typically range from **2.6 to
# 2.65 g/cm³**, but the higher gamma response of the **granitic rock (140–290 gAPI)** can often
# differentiate granitic compositions from **intermediate compositions (70–210 gAPI).** The **higher
# density (2.7–3.0 g/cm³) and lower gamma values (50–80 gAPI) of the dioritic compositions** is
# more distinctive and greatly simplifies identification.
#
# The various laboratory analyses and geophysical logs of the 58-32 well prove it was drilled into **low porosity/low permeability intrusive rock** with temperatures well within the U.S. Department of Energy-specified window of **175°–225°C (347°–437°F).** More details here https://utahforge.com/

# %% [markdown]
# ### Let's import the libraries, remember Lasio and Seaborn must be installed previously

# %%
import lasio
import pandas as pd
import numpy as np
#libraries for plots
import matplotlib.pyplot as plt
import seaborn as sns
#to avoid warnings to show up
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Read 58-32 well logs with Lasio and inspect

# %%
reg_all = lasio.read('../alldata/58-32_main.las')

# %%
reg_all.version
# Out:
# [HeaderItem(mnemonic="VERS", unit="", value="2.0", descr="CWLS Log ASCII Stan...),
#  HeaderItem(mnemonic="WRAP", unit="", value="NO", descr="One Line per depth s...),
#  HeaderItem(mnemonic="PROD", unit="", value="Schlumberger", descr="LAS Producer"),
#  HeaderItem(mnemonic="PROG", unit="", value="DLIS to ASCII 19C2-270", descr="...),
#  HeaderItem(mnemonic="CREA", unit="", value="2017/09/15 13:27                ...),
#  HeaderItem(mnemonic="DLIS_CREA", unit="", value="2017-Sep-15 13:21          ...),
#  HeaderItem(mnemonic="SOURCE", unit="", value="D5RL-00187_University of Utah_...),
#  HeaderItem(mnemonic="FILE-ID", unit="", value="ConPr_R02_L003Up_AIT_HDRS_HGN...)]

# %%
reg_all.curves
# Out:
# [CurveItem(mnemonic="DEPT", unit="F", value="", descr="DEPTH (BOREHOLE) {F10.1}", original_mnemonic="DEPT", data.shape=(15128,)),
#  CurveItem(mnemonic="AF10", unit="OHMM", value="", descr="Array Induction Four Foot Resistivity A10 {F11.4}", original_mnemonic="AF10", data.shape=(15128,)),
#  CurveItem(mnemonic="AF20", unit="OHMM", value="", descr="Array Induction Four Foot Resistivity A20 {F11.4}", original_mnemonic="AF20", data.shape=(15128,)),
#  CurveItem(mnemonic="AF30", unit="OHMM", value="", descr="Array Induction Four Foot Resistivity A30 {F11.4}", original_mnemonic="AF30", data.shape=(15128,)),
#  CurveItem(mnemonic="AF60", unit="OHMM", value="", descr="Array Induction Four Foot Resistivity A60 {F11.4}", original_mnemonic="AF60", data.shape=(15128,)),
#  CurveItem(mnemonic="AF90", unit="OHMM", value="", descr="Array Induction Four Foot Resistivity A90 {F11.4}", original_mnemonic="AF90", data.shape=(15128,)),
#  CurveItem(mnemonic="AO10", unit="OHMM", value="", descr="Array Induction One Foot Resistivity A10 {F11.4}", original_mnemonic="AO10", data.shape=(15128,)),
#  CurveItem(mnemonic="AO20", unit="OHMM", value="", descr="Array Induction One Foot Resistivity A20 {F11.4}", original_mnemonic="AO20", data.shape=(15128,)),
#  CurveItem(mnemonic="AO30", unit="OHMM", value="", descr="Array Induction One Foot Resistivity A30 {F11.4}", original_mnemonic="AO30", data.shape=(15128,)),
#  CurveItem(mnemonic="AO60", unit="OHMM", value="", descr="Array Induction One Foot Resistivity A60 {F11.4}", original_mnemonic="AO60", data.shape=(15128,)),
#  CurveItem(mnemonic="AO90", unit="OHMM", value="", descr="Array Induction One Foot Resistivity A90 {F11.4}", original_mnemonic="AO90", data.shape=(15128,)),
#  CurveItem(mnemonic="AT10", unit="OHMM", value="", descr="Array Induction Two Foot Resistivity A10 {F11.4}", original_mnemonic="AT10", data.shape=(15128,)),
#  CurveItem(mnemonic="AT20", unit="OHMM", value="", descr="Array Induction Two Foot Resistivity A20 {F11.4}", original_mnemonic="AT20", data.shape=(15128,)),
#  CurveItem(mnemonic="AT30", unit="OHMM", value="", descr="Array Induction Two Foot Resistivity A30 {F11.4}", original_mnemonic="AT30", data.shape=(15128,)),
#  CurveItem(mnemonic="AT60", unit="OHMM", value="", descr="Array Induction Two Foot Resistivity A60 {F11.4}", original_mnemonic="AT60", data.shape=(15128,)),
#  CurveItem(mnemonic="AT90", unit="OHMM", value="", descr="Array Induction Two Foot Resistivity A90 {F11.4}", original_mnemonic="AT90", data.shape=(15128,)),
#  CurveItem(mnemonic="AORT", unit="OHMM", value="", descr="Array Induction One Foot Rt {F11.4}", original_mnemonic="AORT", data.shape=(15128,)),
#  CurveItem(mnemonic="AORX", unit="OHMM", value="", descr="Array Induction One Foot Rxo {F11.4}", original_mnemonic="AORX", data.shape=(15128,)),
#  CurveItem(mnemonic="CDF", unit="LBF", value="", descr="Calibrated Downhole Force {F11.4}", original_mnemonic="CDF", data.shape=(15128,)),
#  CurveItem(mnemonic="CFTC", unit="HZ", value="", descr="Corrected Far Thermal Count Rate {F11.4}", original_mnemonic="CFTC", data.shape=(15128,)),
#  CurveItem(mnemonic="CNTC", unit="HZ", value="", descr="Corrected Near Thermal Count Rate {F11.4}", original_mnemonic="CNTC", data.shape=(15128,)),
#  CurveItem(mnemonic="CTEM", unit="DEGF", value="", descr="Cartridge Temperature {F11.4}", original_mnemonic="CTEM", data.shape=(15128,)),
#  CurveItem(mnemonic="DCAL", unit="IN", value="", descr="Differential Caliper {F11.4}", original_mnemonic="DCAL", data.shape=(15128,)),
#  CurveItem(mnemonic="DNPH", unit="CFCF", value="", descr="Difference between Corrected Thermal Neutron Porosity and Uncorrected {F11.4}", original_mnemonic="DNPH", data.shape=(15128,)),
#  CurveItem(mnemonic="DPHZ", unit="CFCF", value="", descr="Standard Resolution Density Porosity {F11.4}", original_mnemonic="DPHZ", data.shape=(15128,)),
#  CurveItem(mnemonic="DSOZ", unit="IN", value="", descr="Standard Resolution Density Standoff {F11.4}", original_mnemonic="DSOZ", data.shape=(15128,)),
#  CurveItem(mnemonic="ECGR", unit="GAPI", value="", descr="Environmentally Corrected Gamma Ray {F11.4}", original_mnemonic="ECGR", data.shape=(15128,)),
#  CurveItem(mnemonic="ED", unit="F", value="", descr="East Departure {F11.4}", original_mnemonic="ED", data.shape=(15128,)),
#  CurveItem(mnemonic="GDEV", unit="DEG", value="", descr="HGNS Hole Deviation from Gravity {F11.4}", original_mnemonic="GDEV", data.shape=(15128,)),
#  CurveItem(mnemonic="GR", unit="GAPI", value="", descr="Gamma Ray {F11.4}", original_mnemonic="GR", data.shape=(15128,)),
#  CurveItem(mnemonic="GR_EDTC", unit="GAPI", value="", descr="Gamma Ray {F11.4}", original_mnemonic="GR_EDTC", data.shape=(15128,)),
#  CurveItem(mnemonic="GTEM", unit="DEGF", value="", descr="Generalized Borehole Temperature {F11.4}", original_mnemonic="GTEM", data.shape=(15128,)),
#  CurveItem(mnemonic="HCAL", unit="IN", value="", descr="HRCC Caliper Calibrated {F11.4}", original_mnemonic="HCAL", data.shape=(15128,)),
#  CurveItem(mnemonic="HDRA", unit="G/C3", value="", descr="Density Standoff Correction {F11.4}", original_mnemonic="HDRA", data.shape=(15128,)),
#  CurveItem(mnemonic="HDRB", unit="G/C3", value="", descr="Difference Between Bulk Density (RHOZ) and Apparent Density from Back Scatter Monosensor Inversion (RHBA) {F11.4}", original_mnemonic="HDRB", data.shape=(15128,)),
#  CurveItem(mnemonic="HGR", unit="GAPI", value="", descr="High Resolution Gamma Ray {F11.4}", original_mnemonic="HGR", data.shape=(15128,)),
#  CurveItem(mnemonic="HMIN", unit="OHMM", value="", descr="HIP Micro Inverse Resistivity {F11.4}", original_mnemonic="HMIN", data.shape=(15128,)),
#  CurveItem(mnemonic="HMNO", unit="OHMM", value="", descr="HIP Micro Normal Resistivity {F11.4}", original_mnemonic="HMNO", data.shape=(15128,)),
#  CurveItem(mnemonic="HNPO", unit="CFCF", value="", descr="High Resolution Enhanced Thermal Neutron Porosity in Selected Lithology {F11.4}", original_mnemonic="HNPO", data.shape=(15128,)),
#  CurveItem(mnemonic="HPRA", unit="", value="", descr="Photoelectric Factor Correction {F11.4}", original_mnemonic="HPRA", data.shape=(15128,)),
#  CurveItem(mnemonic="HTNP", unit="CFCF", value="", descr="High Resolution Thermal Neutron Porosity (Ratio Method) in Selected Lithology {F11.4}", original_mnemonic="HTNP", data.shape=(15128,)),
#  CurveItem(mnemonic="ND", unit="F", value="", descr="North Departure {F11.4}", original_mnemonic="ND", data.shape=(15128,)),
#  CurveItem(mnemonic="NPHI", unit="CFCF", value="", descr="Thermal Neutron Porosity (original Ratio Method) in Selected Lithology {F11.4}", original_mnemonic="NPHI", data.shape=(15128,)),
#  CurveItem(mnemonic="NPOR", unit="CFCF", value="", descr="Enhanced Thermal Neutron Porosity in Selected Lithology {F11.4}", original_mnemonic="NPOR", data.shape=(15128,)),
#  CurveItem(mnemonic="PEFZ", unit="", value="", descr="Standard Resolution Formation Photoelectric Factor {F11.4}", original_mnemonic="PEFZ", data.shape=(15128,)),
#  CurveItem(mnemonic="PXND_HILT", unit="CFCF", value="", descr="Crossplot Porosity from HILT Lithology Computation {F11.4}", original_mnemonic="PXND_HILT", data.shape=(15128,)),
#  CurveItem(mnemonic="RHOZ", unit="G/C3", value="", descr="Standard Resolution Formation Density {F11.4}", original_mnemonic="RHOZ", data.shape=(15128,)),
#  CurveItem(mnemonic="RSOZ", unit="IN", value="", descr="Resistivity Standoff Standard Resolution {F11.4}", original_mnemonic="RSOZ", data.shape=(15128,)),
#  CurveItem(mnemonic="RWA_HILT", unit="OHMM", value="", descr="Apparent Formation Water Resistivity from HILT Lithology Computation {F11.4}", original_mnemonic="RWA_HILT", data.shape=(15128,)),
#  CurveItem(mnemonic="RXO8", unit="OHMM", value="", descr="Invaded Formation Resistivity filtered at 8 inches {F11.4}", original_mnemonic="RXO8", data.shape=(15128,)),
#  CurveItem(mnemonic="RXOZ", unit="OHMM", value="", descr="Invaded Formation Resistivity filtered at 18 inches {F11.4}", original_mnemonic="RXOZ", data.shape=(15128,)),
#  CurveItem(mnemonic="SP", unit="MV", value="", descr="Spontaneous Potential {F11.4}", original_mnemonic="SP", data.shape=(15128,)),
#  CurveItem(mnemonic="SPAR", unit="MV", value="", descr="SP, Armor Return Compensated {F11.4}", original_mnemonic="SPAR", data.shape=(15128,)),
#  CurveItem(mnemonic="STIT", unit="F", value="", descr="Stuck Tool Indicator, Total {F11.4}", original_mnemonic="STIT", data.shape=(15128,)),
#  CurveItem(mnemonic="TENS", unit="LBF", value="", descr="Cable Tension {F11.4}", original_mnemonic="TENS", data.shape=(15128,)),
#  CurveItem(mnemonic="TNPH", unit="CFCF", value="", descr="Thermal Neutron Porosity (Ratio Method) in Selected Lithology {F11.4}", original_mnemonic="TNPH", data.shape=(15128,)),
#  CurveItem(mnemonic="HTNP_SAN", unit="CFCF", value="", descr="HiRes Thermal Neutron Porosity (matrix Sandstone) {F11.4}", original_mnemonic="HTNP_SAN", data.shape=(15128,)),
#  CurveItem(mnemonic="ATCO10", unit="MM/M", value="", descr="Array Induction Two Foot Conductivity A10 {F13.4}", original_mnemonic="ATCO10", data.shape=(15128,)),
#  CurveItem(mnemonic="ATCO20", unit="MM/M", value="", descr="Array Induction Two Foot Conductivity A20 {F13.4}", original_mnemonic="ATCO20", data.shape=(15128,)),
#  CurveItem(mnemonic="ATCO30", unit="MM/M", value="", descr="Array Induction Two Foot Conductivity A30 {F13.4}", original_mnemonic="ATCO30", data.shape=(15128,)),
#  CurveItem(mnemonic="ATCO60", unit="MM/M", value="", descr="Array Induction Two Foot Conductivity A60 {F13.4}", original_mnemonic="ATCO60", data.shape=(15128,)),
#  CurveItem(mnemonic="ATCO90", unit="MM/M", value="", descr="Array Induction Two Foot Conductivity A90 {F13.4}", original_mnemonic="ATCO90", data.shape=(15128,))]

# %%
reg_all.data
# Out:
# array([[1.050000e+01, 1.104000e+00, 4.224000e-01, ..., 3.567750e+01,
#         1.414420e+01, 5.066640e+01],
#        [1.100000e+01, 1.104000e+00, 4.224000e-01, ..., 3.567750e+01,
#         1.414420e+01, 5.066640e+01],
#        [1.150000e+01, 1.104000e+00, 4.224000e-01, ..., 3.567750e+01,
#         1.414420e+01, 5.066640e+01],
#        ...,
#        [7.573000e+03, 1.950000e+03, 2.362897e+02, ..., 7.465900e+00,
#         1.864200e+00, 5.000000e-01],
#        [7.573500e+03, 1.950000e+03, 2.362897e+02, ..., 7.465900e+00,
#         1.864200e+00, 5.000000e-01],
#        [7.574000e+03, 1.950000e+03, 2.362897e+02, ..., 7.465900e+00,
#         1.864200e+00, 5.000000e-01]])

# %%
reg_all.keys()
# Out:
# ['DEPT',
#  'AF10',
#  'AF20',
#  'AF30',
#  'AF60',
#  'AF90',
#  'AO10',
#  'AO20',
#  'AO30',
#  'AO60',
#  'AO90',
#  'AT10',
#  'AT20',
#  'AT30',
#  'AT60',
#  'AT90',
#  'AORT',
#  'AORX',
#  'CDF',
#  'CFTC',
#  'CNTC',
#  'CTEM',
#  'DCAL',
#  'DNPH',
#  'DPHZ',
#  'DSOZ',
#  'ECGR',
#  'ED',
#  'GDEV',
#  'GR',
#  'GR_EDTC',
#  'GTEM',
#  'HCAL',
#  'HDRA',
#  'HDRB',
#  'HGR',
#  'HMIN',
#  'HMNO',
#  'HNPO',
#  'HPRA',
#  'HTNP',
#  'ND',
#  'NPHI',
#  'NPOR',
#  'PEFZ',
#  'PXND_HILT',
#  'RHOZ',
#  'RSOZ',
#  'RWA_HILT',
#  'RXO8',
#  'RXOZ',
#  'SP',
#  'SPAR',
#  'STIT',
#  'TENS',
#  'TNPH',
#  'HTNP_SAN',
#  'ATCO10',
#  'ATCO20',
#  'ATCO30',
#  'ATCO60',
#  'ATCO90']

# %%
reg_all['SP']
# Out:
# array([    nan,     nan,     nan, ..., 64.9519, 59.6354, 51.4583])

# %% [markdown]
# ### From Lasio to Data Frame Pandas
# DataFrames in Pandas are two-dimensional tables with row and columns that can be easily edited and manipulated.

# %%
df_main = reg_all.df()
df_main
# Out:
#             AF10      AF20      AF30       AF60       AF90       AO10  \
# DEPT
# 10.5       1.104    0.4224   20.9881  1950.0000    44.9381     1.1341
# 11.0       1.104    0.4224   20.9881  1950.0000    44.9381     1.1341
# 11.5       1.104    0.4224   20.9881  1950.0000    44.9381     1.1341
# 12.0       1.104    0.4224   20.9881  1950.0000    44.9381     1.1341
# 12.5       1.104    0.4224   20.9881  1950.0000    44.9381     1.1341
# ...          ...       ...       ...        ...        ...        ...
# 7572.0  1950.000  236.2897  135.8063   555.1772  1950.0000  1950.0000
# 7572.5  1950.000  236.2897  135.8063   555.1772  1950.0000  1950.0000
# 7573.0  1950.000  236.2897  135.8063   555.1772  1950.0000  1950.0000
# 7573.5  1950.000  236.2897  135.8063   555.1772  1950.0000  1950.0000
# 7574.0  1950.000  236.2897  135.8063   555.1772  1950.0000  1950.0000
#
#             AO20      AO30      AO60       AO90  ...     SPAR  STIT  \
# DEPT                                             ...
# 10.5      0.5586    2.1295    1.7824     2.5706  ...      NaN   0.0
# 11.0      0.5586    2.1295    1.7824     2.5706  ...      NaN   0.0
# 11.5      0.5586    2.1295    1.7824     2.5706  ...      NaN   0.0
# 12.0      0.5586    2.1295    1.7824     2.5706  ...      NaN   0.0
# 12.5      0.5586    2.1295    1.7824     2.5706  ...      NaN   0.0
# ...          ...       ...       ...        ...  ...      ...   ...
# 7572.0  172.8385  130.5535  489.0653  1240.9810  ...  63.9401   0.0
# 7572.5  172.8385  130.5535  489.0653  1240.9810  ...  61.6204   0.0
# 7573.0  172.8385  130.5535  489.0653  1240.9810  ...  59.4630   0.0
# 7573.5  172.8385  130.5535  489.0653  1240.9810  ...  57.5104   0.0
# 7574.0  172.8385  130.5535  489.0653  1240.9810  ...  55.7997   0.0
#
#              TENS  TNPH  HTNP_SAN    ATCO10     ATCO20   ATCO30   ATCO60  \
# DEPT
# 10.5     940.9999   NaN    0.3744  840.4879  2040.4220  35.6775  14.1442
# 11.0     940.9999   NaN    0.3744  840.4879  2040.4220  35.6775  14.1442
# 11.5     940.9999   NaN    0.3744  840.4879  2040.4220  35.6775  14.1442
# 12.0     940.9999   NaN    0.3744  840.4879  2040.4220  35.6775  14.1442
# 12.5     940.9999   NaN    0.3744  840.4879  2040.4220  35.6775  14.1442
# ...           ...   ...       ...       ...        ...      ...      ...
# 7572.0  1863.3334   NaN       NaN    0.5000     5.4373   7.4659   1.8642
# 7572.5  1886.5000   NaN       NaN    0.5000     5.4373   7.4659   1.8642
# 7573.0  1870.5000   NaN       NaN    0.5000     5.4373   7.4659   1.8642
# 7573.5  1783.5000   NaN       NaN    0.5000     5.4373   7.4659   1.8642
# 7574.0  1545.5000   NaN       NaN    0.5000     5.4373   7.4659   1.8642
#
#          ATCO90
# DEPT
# 10.5    50.6664
# 11.0    50.6664
# 11.5    50.6664
# 12.0    50.6664
# 12.5    50.6664
# ...         ...
# 7572.0   0.5000
# 7572.5   0.5000
# 7573.0   0.5000
# 7573.5   0.5000
# 7574.0   0.5000
#
# [15128 rows x 61 columns]

# %%
#Print the first 5 rows of the data frame with the header of the columns
df_main.head(5)
# Out:
#        AF10    AF20     AF30    AF60     AF90    AO10    AO20    AO30    AO60  \
# DEPT
# 10.5  1.104  0.4224  20.9881  1950.0  44.9381  1.1341  0.5586  2.1295  1.7824
# 11.0  1.104  0.4224  20.9881  1950.0  44.9381  1.1341  0.5586  2.1295  1.7824
# 11.5  1.104  0.4224  20.9881  1950.0  44.9381  1.1341  0.5586  2.1295  1.7824
# 12.0  1.104  0.4224  20.9881  1950.0  44.9381  1.1341  0.5586  2.1295  1.7824
# 12.5  1.104  0.4224  20.9881  1950.0  44.9381  1.1341  0.5586  2.1295  1.7824
#
#         AO90  ...  SPAR  STIT      TENS  TNPH  HTNP_SAN    ATCO10    ATCO20  \
# DEPT          ...
# 10.5  2.5706  ...   NaN   0.0  940.9999   NaN    0.3744  840.4879  2040.422
# 11.0  2.5706  ...   NaN   0.0  940.9999   NaN    0.3744  840.4879  2040.422
# 11.5  2.5706  ...   NaN   0.0  940.9999   NaN    0.3744  840.4879  2040.422
# 12.0  2.5706  ...   NaN   0.0  940.9999   NaN    0.3744  840.4879  2040.422
# 12.5  2.5706  ...   NaN   0.0  940.9999   NaN    0.3744  840.4879  2040.422
#
#        ATCO30   ATCO60   ATCO90
# DEPT
# 10.5  35.6775  14.1442  50.6664
# 11.0  35.6775  14.1442  50.6664
# 11.5  35.6775  14.1442  50.6664
# 12.0  35.6775  14.1442  50.6664
# 12.5  35.6775  14.1442  50.6664
#
# [5 rows x 61 columns]

# %%
#Print the last 10 rows of the data frame with the header of the columns
df_main.tail(10)
# Out:
#           AF10      AF20      AF30      AF60    AF90    AO10      AO20  \
# DEPT
# 7569.5  1950.0  236.2897  135.8063  555.1772  1950.0  1950.0  172.8385
# 7570.0  1950.0  236.2897  135.8063  555.1772  1950.0  1950.0  172.8385
# 7570.5  1950.0  236.2897  135.8063  555.1772  1950.0  1950.0  172.8385
# 7571.0  1950.0  236.2897  135.8063  555.1772  1950.0  1950.0  172.8385
# 7571.5  1950.0  236.2897  135.8063  555.1772  1950.0  1950.0  172.8385
# 7572.0  1950.0  236.2897  135.8063  555.1772  1950.0  1950.0  172.8385
# 7572.5  1950.0  236.2897  135.8063  555.1772  1950.0  1950.0  172.8385
# 7573.0  1950.0  236.2897  135.8063  555.1772  1950.0  1950.0  172.8385
# 7573.5  1950.0  236.2897  135.8063  555.1772  1950.0  1950.0  172.8385
# 7574.0  1950.0  236.2897  135.8063  555.1772  1950.0  1950.0  172.8385
#
#             AO30      AO60      AO90  ...     SPAR  STIT       TENS  TNPH  \
# DEPT                                  ...
# 7569.5  130.5535  489.0653  1240.981  ...  75.8117   0.0  1869.6669   NaN
# 7570.0  130.5535  489.0653  1240.981  ...  73.5860   0.0  1852.4999   NaN
# 7570.5  130.5535  489.0653  1240.981  ...  71.2383   0.0  1862.5000   NaN
# 7571.0  130.5535  489.0653  1240.981  ...  68.7968   0.0  1883.5000   NaN
# 7571.5  130.5535  489.0653  1240.981  ...  66.3411   0.0  1886.5000   NaN
# 7572.0  130.5535  489.0653  1240.981  ...  63.9401   0.0  1863.3334   NaN
# 7572.5  130.5535  489.0653  1240.981  ...  61.6204   0.0  1886.5000   NaN
# 7573.0  130.5535  489.0653  1240.981  ...  59.4630   0.0  1870.5000   NaN
# 7573.5  130.5535  489.0653  1240.981  ...  57.5104   0.0  1783.5000   NaN
# 7574.0  130.5535  489.0653  1240.981  ...  55.7997   0.0  1545.5000   NaN
#
#         HTNP_SAN  ATCO10  ATCO20  ATCO30  ATCO60  ATCO90
# DEPT
# 7569.5       NaN     0.5  5.4373  7.4659  1.8642     0.5
# 7570.0       NaN     0.5  5.4373  7.4659  1.8642     0.5
# 7570.5       NaN     0.5  5.4373  7.4659  1.8642     0.5
# 7571.0       NaN     0.5  5.4373  7.4659  1.8642     0.5
# 7571.5       NaN     0.5  5.4373  7.4659  1.8642     0.5
# 7572.0       NaN     0.5  5.4373  7.4659  1.8642     0.5
# 7572.5       NaN     0.5  5.4373  7.4659  1.8642     0.5
# 7573.0       NaN     0.5  5.4373  7.4659  1.8642     0.5
# 7573.5       NaN     0.5  5.4373  7.4659  1.8642     0.5
# 7574.0       NaN     0.5  5.4373  7.4659  1.8642     0.5
#
# [10 rows x 61 columns]

# %%
# statistics
df_main.describe()
# Out:
#                AF10          AF20          AF30          AF60          AF90  \
# count  15128.000000  15128.000000  15128.000000  15128.000000  15128.000000
# mean    1057.333747    263.127052    700.465042    461.520809    381.994623
# std      960.930442    482.651697    761.186149    609.400238    508.962946
# min        0.305500      0.268500      2.100700      1.801000      2.246500
# 25%        1.308625      9.279650     63.498300     16.123850     12.978125
# 50%     1950.000000     78.383800    309.246950    206.005750    125.401400
# 75%     1950.000000    237.964750   1495.696475    585.191750    575.557450
# max     1950.000000   1950.000000   1950.000000   1950.000000   1950.000000
#
#                AO10          AO20          AO30          AO60          AO90  \
# count  15128.000000  15128.000000  15128.000000  15128.000000  15128.000000
# mean     865.252372    153.066751    171.764185    129.328144    143.574630
# std      924.528355    311.569883    298.766152    234.957880    258.862107
# min        0.147400      0.124500      0.195500      0.175400      0.175000
# 25%        1.134100      4.099400      6.042300      3.432100      5.099600
# 50%      162.547450     42.304600     44.958750     32.941450     34.913950
# 75%     1950.000000    161.955375    215.931900    156.174500    172.687025
# max     1950.000000   1950.000000   1950.000000   1950.000000   1950.000000
#
#        ...          SPAR          STIT         TENS          TNPH  \
# count  ...  15050.000000  15128.000000  15128.00000  15050.000000
# mean   ...     41.074056      0.009489   1961.43714     -0.195683
# std    ...     66.226484      0.207322    677.87897     44.995154
# min    ...   -184.830400      0.000000    837.00000  -5519.708800
# 25%    ...     -0.792350      0.000000   1349.00000      0.018900
# 50%    ...     50.583000      0.000000   1881.00010      0.105250
# 75%    ...     77.533450      0.000000   2523.00000      0.295775
# max    ...    170.024600      7.137100   3657.00000      1.938200
#
#            HTNP_SAN        ATCO10        ATCO20        ATCO30        ATCO60  \
# count  15066.000000  15128.000000  15128.000000  15128.000000  15128.000000
# mean       0.171299    529.448157    384.797785     25.741978     36.735270
# std        0.202024    939.346597    743.361420     54.083445     69.638867
# min       -0.033700      0.128700      0.437600    -19.974200      0.421200
# 25%        0.019000      0.500000      4.869850      1.388725      2.580375
# 50%        0.105950      0.513900     15.529700      4.170750      7.276800
# 75%        0.296500    787.352975    191.873450     26.002250     66.544900
# max        1.957800   4771.050800   4863.314000   1020.361100   2169.789100
#
#              ATCO90
# count  15128.000000
# mean      68.613872
# std      107.163454
# min        0.403300
# 25%        2.519000
# 50%       12.554050
# 75%       89.583625
# max     2210.575400
#
# [8 rows x 61 columns]

# %%
#parameters from only 1 column 
df_main.AF10.std()
# Out:
# 960.9304424401018

# %% [markdown]
# ### Create a dataset only with GR, SP, AT10, AT90, RHOZ, NPHI, CTEM

# %%
df_mini = df_main[['GR', 'SP', 'AT10', 'AT90', 'RHOZ', 'NPHI', 'CTEM']]

# %%
df_mini.describe()
# Out:
#                  GR            SP          AT10          AT90          RHOZ  \
# count  15128.000000  15050.000000  15128.000000  15128.000000  15082.000000
# mean     142.765148     41.073123   1023.753314    288.923367      2.188006
# std       69.231103     66.289773    956.316490    433.237908     45.014033
# min       17.610800   -181.250000      0.209600      0.452400  -5525.473100
# 25%       85.743550     -0.423175      1.270075     11.162750      2.428400
# 50%      149.707250     50.625000   1945.940800     79.655500      2.568900
# 75%      179.402750     77.421900   1950.000000    396.977950      2.616875
# max      641.089700    172.656300   1950.000000   1950.000000      4.628800
#
#                NPHI          CTEM
# count  15112.000000  15128.000000
# mean       0.146351    216.427223
# std        0.167891     43.016193
# min       -0.011600    141.835300
# 25%        0.013700    179.388200
# 50%        0.080200    216.941200
# 75%        0.264225    256.470600
# max        0.862100    280.188200

# %%
df_mini['CTEM_C']= ((df_mini['CTEM']-32)*5)/9

# %%
df_mini.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 15128 entries, 10.5 to 7574.0
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   GR      15128 non-null  float64
#  1   SP      15050 non-null  float64
#  2   AT10    15128 non-null  float64
#  3   AT90    15128 non-null  float64
#  4   RHOZ    15082 non-null  float64
#  5   NPHI    15112 non-null  float64
#  6   CTEM    15128 non-null  float64
#  7   CTEM_C  15128 non-null  float64
# dtypes: float64(8)
# memory usage: 1.0 MB

# %%
count_neg = (df_mini.RHOZ < 0).sum()
count_neg
# Out:
# 1

# %%
df_mini.loc[(df_mini['RHOZ'] < 0), 'RHOZ']=np.nan

# %%
count_neg = (df_mini.RHOZ < 0).sum()
count_neg
# Out:
# 0

# %% [markdown]
# **Unknown LowGR (<50)
# **Dioritic comp. (50–80 gAPI)
# **Intermediate comp. (80–140 gAPI)
# **Granite (140–290 gAPI)
# **Unknown HighGR(>290)

# %%
conditions = [
    (df_mini['GR'] <= 50),
    (df_mini['GR'] > 50) & (df_mini['GR'] <= 80),
    (df_mini['GR'] > 80) & (df_mini['GR'] <= 140),
    (df_mini['GR'] > 140) & (df_mini['GR'] <= 290),
    (df_mini['GR'] > 290)
    ]

# create a list of the values we want to assign for each condition
values = ['Unknown LowGR', 'Dioritic Comp', 'Intermediate Comp', 'Granite', 'Unknown HighGR' ]

# create a new column and use np.select to assign values to it using our lists as arguments
df_mini['Labels'] = np.select(conditions, values)

# %%
df_mini.sample(10)
# Out:
#               GR        SP       AT10      AT90    RHOZ    NPHI      CTEM  \
# DEPT
# 642.0    84.2288   46.1806     0.9405   17.3580  2.2932  0.3474  153.6941
# 6367.0  211.3432  106.8750  1950.0000  850.9054  2.5986  0.0101  270.3059
# 3166.0  169.6880  -52.5000    17.4033   11.6871  2.4536  0.1144  203.1059
# 984.0    81.9454   56.0938     0.8745    2.8525  2.4160  0.4280  159.6235
# 1805.0  101.0975   44.2361     0.3738    4.4273  2.6280  0.2239  177.4118
# 2985.0  159.8126  -53.7500    16.7280   13.3307  2.3959  0.1561  201.1294
# 4539.0  146.6294   51.5625  1950.0000  544.3677  2.6356  0.0137  232.7529
# 1975.5   88.1395   41.8750     0.3678    4.4901  2.9112  0.2510  181.3647
# 1082.0   91.5069   51.7969     0.5929   22.9596  2.2909  0.4316  161.6000
# 3673.0   69.5595  -72.3611  1950.0000  118.4404  2.6799  0.0622  212.9882
#
#             CTEM_C             Labels
# DEPT
# 642.0    67.607833  Intermediate Comp
# 6367.0  132.392167            Granite
# 3166.0   95.058833            Granite
# 984.0    70.901944  Intermediate Comp
# 1805.0   80.784333  Intermediate Comp
# 2985.0   93.960778            Granite
# 4539.0  111.529389            Granite
# 1975.5   82.980389  Intermediate Comp
# 1082.0   72.000000  Intermediate Comp
# 3673.0  100.549000      Dioritic Comp

# %%
#statistics grouped by Labels 

df_mini[['Labels','GR', 'SP', 'AT10', 'AT90', 'RHOZ', 'NPHI', 'CTEM', 'CTEM_C']].groupby('Labels').mean()
# Out:
#                            GR         SP         AT10        AT90      RHOZ  \
# Labels
# Dioritic Comp       69.123712 -10.088922  1079.068284  100.589511  2.622031
# Granite            185.445624  54.325912  1347.089075  439.662353  2.534700
# Intermediate Comp   99.063707  36.043228   499.784752   99.625447  2.592993
# Unknown HighGR     358.966913  62.465258  1803.807138  837.407983  2.557192
# Unknown LowGR       34.589060  64.025297    41.659378   20.957278  2.348038
#
#                        NPHI        CTEM      CTEM_C
# Labels
# Dioritic Comp      0.192566  197.285916   91.825509
# Granite            0.048244  241.648139  116.471188
# Intermediate Comp  0.244857  187.430945   86.350525
# Unknown HighGR     0.015230  256.405752  124.669862
# Unknown LowGR      0.567986  148.022027   64.456682

# %% [markdown]
# ### Read Thermal conductivity and mineralogy data measured in drill cuttings. CAUTION: Depths are in meters, need to be converted to feet
# ##### Full report https://ugspub.nr.utah.gov/publications/misc_pubs/mp-169/mp-169-l.pdf

# %%
TC_coredata = pd.read_csv ('../alldata/58-32_thermal_conductivity_data.csv', index_col=1)
XRD_coredata = pd.read_csv ('../alldata/58-32_xray_diffraction_data.csv', index_col=1)

#TC_coredata.head()
XRD_coredata.columns
# Out:
# Index(['Lower Depth Range (m)', 'Smectite', 'Illite', 'Chlorite',
#        'Interlayered\nChlorite-Smectite', '% chlorite in C/S', 'Kaolinite',
#        'Biotite', 'Hornblende', 'Augite', 'Titanite', 'Apatite', 'Plagioclase',
#        'K-feldspar', 'Quartz', 'Epidote', 'Calcite', 'Dolomite', 'Siderite',
#        'Anhydrite', 'Hematite'],
#       dtype='object')

# %%
TC_coredata.index
# Out:
# Float64Index([  33.5,   64.0,   94.5,  125.0,  155.4,  185.9,  216.4,  246.9,
#                277.4,  307.8,  338.3,  368.8,  399.3,  429.7,  460.2,  490.7,
#                521.2,  551.7,  582.1,  612.6,  643.1,  673.6,  704.1,  734.5,
#                765.0,  795.5,  826.0,  856.4,  886.9,  917.4,  947.9,  978.4,
#               1008.8, 1039.3, 1069.8, 1100.3, 1130.8, 1161.2, 1191.7, 1222.2,
#               1252.7, 1283.1, 1313.6, 1344.1, 1374.6, 1405.1, 1435.5, 1466.0,
#               1496.5, 1527.0, 1557.5, 1587.9, 1618.4, 1648.9, 1679.4, 1709.8,
#               1740.3, 1770.8, 1801.3, 1831.8, 1862.2, 1892.7, 1923.2, 1953.7,
#               1984.2, 2014.6, 2045.1, 2106.1, 2136.5, 2167.0, 2197.5, 2228.0,
#               2258.5, 2288.9],
#              dtype='float64', name='Upper Depth Interval (m)')

# %%
XRD_coredata.index
# Out:
# Float64Index([  33.5,   64.0,   94.5,  125.0,  155.4,  185.9,  216.4,  246.9,
#                277.4,  307.8,  338.3,  368.8,  399.3,  429.7,  460.2,  490.7,
#                521.2,  551.7,  582.1,  612.6,  643.1,  673.6,  704.1,  734.5,
#                765.0,  795.5,  826.0,  856.4,  886.9,  917.4,  947.9,  969.2,
#                972.3,  975.3,  978.4, 1008.8, 1018.0, 1039.3, 1069.8, 1100.3,
#               1130.8, 1161.2, 1191.7, 1222.2, 1252.7, 1283.1, 1313.6, 1344.1,
#               1374.6, 1405.1, 1435.5, 1466.0, 1496.5, 1527.0, 1557.5, 1587.9,
#               1618.4, 1648.9, 1679.4, 1709.8, 1740.3, 1770.8, 1801.3, 1831.8,
#               1862.2, 1892.7, 1923.2, 1953.7, 1984.2, 2014.6, 2045.1, 2075.6,
#               2106.1, 2136.5, 2167.0, 2197.5, 2228.0, 2258.5, 2288.9],
#              dtype='float64', name='Upper Depth Range (m)')

# %%
result = pd.concat([XRD_coredata, TC_coredata], axis=1, sort=False)

# %%
result.columns
# Out:
# Index(['Lower Depth Range (m)', 'Smectite', 'Illite', 'Chlorite',
#        'Interlayered\nChlorite-Smectite', '% chlorite in C/S', 'Kaolinite',
#        'Biotite', 'Hornblende', 'Augite', 'Titanite', 'Apatite', 'Plagioclase',
#        'K-feldspar', 'Quartz', 'Epidote', 'Calcite', 'Dolomite', 'Siderite',
#        'Anhydrite', 'Hematite', 'Lower Depth Interval (m)',
#        'matrix thermal conductivity (W/m deg C)'],
#       dtype='object')

# %%
cutt_data = result[['Illite','Plagioclase', 'K-feldspar', 
                    'Quartz', 'matrix thermal conductivity (W/m deg C)']]

# %%
cutt_data.index=(3.28084*cutt_data.index) #m to ft
#cutt_data.loc[(cutt_data =='tr')]=np.nan
cutt_data=cutt_data.replace('tr', np.nan)
cutt_data.columns=['Illi', 'Plag', 'K-feld', 'Qz', 'TC']

# %%
cutt_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 79 entries, 109.90814 to 7509.514676000001
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Illi    64 non-null     object
#  1   Plag    79 non-null     int64
#  2   K-feld  79 non-null     int64
#  3   Qz      79 non-null     int64
#  4   TC      74 non-null     float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 3.7+ KB

# %%
cutt_data.sample(5)
# Out:
#             Illi  Plag  K-feld  Qz    TC
# 910.105016   NaN    31      41  28  3.33
# 5809.711472    1    35      29  34  3.72
# 3109.908236    3    38      39  18  2.98
# 3709.973872    5    45      18   4  2.18
# 1909.776964    3    34      41  20  3.25

# %% [markdown]
# # Visualization

# %%
#let's start with something simple

# %%
plt.hist(df_mini['SP'],bins=None, range=None, histtype='bar', orientation='vertical', color=None);

# %%
plt.hist(df_mini['GR'],bins=60, range=None, histtype='step', orientation='horizontal', color='r');

# %%
sns.scatterplot(x=df_mini['RHOZ'], y=df_mini['GR']);

# %%
sns.scatterplot(x=df_mini['RHOZ'], y=df_mini['GR'], hue=df_mini['Labels']);

# %%
sns.relplot(data=df_mini,
    x="RHOZ", y="GR", col="Labels",
    hue="Labels");

# %%
sns.countplot(y=df_mini['Labels']);

# %%
sns.set(style="ticks", context="talk")
plt.style.use('seaborn-paper')
g = sns.PairGrid(df_mini.iloc[:,1:], diag_sharey=False, corner=True);
g.map_lower(sns.scatterplot);
g.map_diag(sns.kdeplot,shade=True, shade_lowest=False);

# %%
#creating correlation matrix data
corr = df_mini.corr() #exclude any string data type
#figure parameters
fig, ax = plt.subplots(figsize=(8,6))
sns.heatmap(corr, ax=ax, cmap="magma")
#plt.grid()
plt.show()

# %%
#Creating 2 tracks to plot data form this particular dataframe
fig, axs = plt.subplots(nrows=1, ncols=2, sharey=True, squeeze=True, figsize=(15, 15), gridspec_kw={'wspace': 0.25})
fig.subplots_adjust(left=0.05, bottom=0.05, right=0.975, top=0.7, wspace=0.2, hspace=0.2)
axs[0].set_ylabel('Depth (ft)')
axs[0].invert_yaxis()
axs[0].get_xaxis().set_visible(False)

ax1 = axs[0].twiny()  
ax1.plot(df_mini.GR, df_mini.index, '-', color='#2ea869', linewidth=0.5)
ax1.set_xlim(0,450) 
ax1.set_xlabel('GR (API)', color='#2ea869')
ax1.minorticks_on()
ax1.spines['top'].set_position(('axes', 1.0)) 

ax2 = axs[1].twiny() 
ax2.plot(df_mini.SP, df_mini.index, '-', color='#0a0a0a', linewidth=0.7)
ax2.set_xlim(-200,200) 
ax2.set_xlabel('SP(mV)', color='#0a0a0a')
ax2.minorticks_on()
ax2.spines['top'].set_position(('axes', 1.0))  

#Creating the Grid
ax2.grid(True)
axs[1].get_xaxis().set_visible(False)

# %% [markdown]
# ### Create a function that would create a layout with basic logs and core data

# %%
#Log visualization function, to be able to apply it to any set of data that has been converted to a dataFrame

def make_layout_tc (log_df, cuttings_df):

  
    fig, axs = plt.subplots(nrows=1, ncols=5, sharey=True, squeeze=True, figsize=(15, 15), gridspec_kw={'wspace': 0.25})
    fig.subplots_adjust(left=0.05, bottom=0.05, right=0.975, top=0.7, wspace=0.2, hspace=0.2)
    axs[0].set_ylabel('Depth (ft)')
    axs[0].invert_yaxis()
    axs[0].get_xaxis().set_visible(False)
    
    # First track GR/SP logs to display
    ax1 = axs[0].twiny()  
    ax1.plot(log_df.GR, log_df.index, '-', color='#2ea869', linewidth=0.5)
    ax1.set_xlim(0,450) 
    ax1.set_xlabel('GR (API)', color='#2ea869')
    ax1.minorticks_on()
    ax1.spines['top'].set_position(('axes', 1.075)) 
    
    ax2 = axs[0].twiny() 
    ax2.plot(log_df.SP, log_df.index, '-', color='#0a0a0a', linewidth=0.7)
    ax2.set_xlim(-200,200) 
    ax2.set_xlabel('SP(mV)', color='#0a0a0a')
    ax2.minorticks_on()
    ax2.spines['top'].set_position(('axes', 1.0))    
    ax2.grid(True)
    axs[0].get_xaxis().set_visible(False)
    
    # Second track RHOZ/NPHI logs to display
    ax1 = axs[1].twiny()  
    ax1.plot(log_df.RHOZ, log_df.index, '-', color='#ea0606', linewidth=0.5)
    ax1.set_xlim(1.5,3.0) 
    ax1.set_xlabel('RHOZ (g/cm3)', color='#ea0606')
    ax1.minorticks_on()
    ax1.spines['top'].set_position(('axes', 1.075))

    ax2 = axs[1].twiny()  
    ax2.plot(log_df.NPHI, log_df.index, '-', color='#1577e0', linewidth=0.5)
    ax2.set_xlim(1,0) 
    ax2.set_xlabel('NPHI (v/v)', color='#1577e0')
    ax2.minorticks_on()
    ax2.spines['top'].set_position(('axes', 1.0))
    ax2.grid(True)
    axs[1].get_xaxis().set_visible(False)
    
    # Third track Resistivities
    ax1 = axs[2].twiny()  
    ax1.plot(log_df.AT10, log_df.index, '-', color='#6e787c', linewidth=0.5)
    ax1.set_xlim(0.1,100000)  
    ax1.set_xlabel('AT10 (ohm.m)', color='#6e787c')
    ax1.set_xscale('log')
    ax1.minorticks_on()
    ax1.spines['top'].set_position(('axes', 1.075))
    
    ax2 = axs[2].twiny()  
    ax2.plot(log_df.AT90, log_df.index, '-', color='#ea0606', linewidth=0.5)
    ax2.set_xlim(0.1,100000)  
    ax2.set_xlabel('AT90 (ohm.m)', color='#ea0606')
    ax2.set_xscale('log')
    ax2.minorticks_on()
    ax2.spines['top'].set_position(('axes', 1.0))
    ax2.grid(True)
    axs[2].get_xaxis().set_visible(False)


  # Fourth track XRD to display
    ax1 = axs[3].twiny()  
    ax1.plot(cuttings_df.Qz, cuttings_df.index, 'o', color='#eac406')
    ax1.set_xlim(0,50) 
    ax1.set_xlabel('Quartz %', color='#eac406')
    ax1.minorticks_on()
    ax1.spines['top'].set_position(('axes', 1.075))
    
    ax2 = axs[3].twiny()  
    ax2.plot(cuttings_df.Illi, cuttings_df.index, 'o', color='#94898c')
    ax2.set_xlim(0,50) 
    ax2.set_xlabel('Illite %', color='#94898c')
    ax2.minorticks_on()
    ax2.spines['top'].set_position(('axes', 1.0))
    ax2.grid(True)
    axs[3].get_xaxis().set_visible(False)


    # Fifth track Temp/TC to display
    ax1 = axs[4].twiny()  
    ax1.plot(cuttings_df.TC, cuttings_df.index, 'o', color='#6e787c')
    ax1.set_xlim(0,5) 
    ax1.set_xlabel('Matrix TC Measured W/mC', color='#6e787c')
    ax1.minorticks_on()
    ax1.spines['top'].set_position(('axes', 1.075))

    ax2 = axs[4].twiny()  
    ax2.plot(log_df.CTEM_C, log_df.index, '-', color='#ed8712')
    ax2.set_xlim(20,200) 
    ax2.set_xlabel('Temp degC', color='#ed8712')
    ax2.minorticks_on()
    ax2.spines['top'].set_position(('axes', 1.0))
    ax2.grid(True)
    axs[4].get_xaxis().set_visible(False)
         
    fig.suptitle('Well Data for UTAH FORGE 58-32',weight='bold', fontsize=20, y=0.85);
    plt.show()

# %%
#Applying the data frames, that we have created above, to the function make_layout_tc (inputs)
make_layout_tc (df_mini, cutt_data)

# %% [markdown]
# ## We are Done
